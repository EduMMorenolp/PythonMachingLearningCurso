# %% [markdown]
# <a href="https://colab.research.google.com/github/EduMMorenolp/PythonMachingLearningCurso/blob/master/Python_Maching_Learning_Curso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Maching Learning Curso
# ![Bibliografia.png](data:image/png;base64,...)
